# %%
# %sql
-- Tạo bảng Bronze để chứa dữ liệu thô từ API
CREATE TABLE IF NOT EXISTS workspace.stock_db.bronze_stock_prices (
  symbol STRING,
  open DOUBLE,
  high DOUBLE,
  low DOUBLE,
  close DOUBLE,
  volume LONG,
  adj_close DOUBLE,
  date DATE,
  ingested_at TIMESTAMP
)
USING DELTA;
